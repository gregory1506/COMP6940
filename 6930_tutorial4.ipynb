# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.arima_model import ARIMA

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#      Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0  2004-01                100                31                    48
# 1  2004-02                 75                26                    49
# 2  2004-03                 67                24                    47
# 3  2004-04                 70                22                    48
# 4  2004-05                 72                22                    43

# %%
df.describe()
# Out:
#        diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# count         168.000000        168.000000            168.000000
# mean           49.642857         34.690476             47.148810
# std             8.033080          8.134316              4.972547
# min            34.000000         22.000000             38.000000
# 25%            44.000000         28.000000             44.000000
# 50%            48.500000         32.500000             46.000000
# 75%            53.000000         41.000000             50.000000
# max           100.000000         58.000000             73.000000

# %%
df.shape
# Out:
# (168, 4)

# %%
df.dtypes
# Out:
# Month                   object
# diet: (Worldwide)        int64
# gym: (Worldwide)         int64
# finance: (Worldwide)     int64
# dtype: object

# %%
df.Month = pd.to_datetime(df.Month)
df.set_index('Month',inplace=True)
df.head()
# Out:
#             diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# Month
# 2004-01-01                100                31                    48
# 2004-02-01                 75                26                    49
# 2004-03-01                 67                24                    47
# 2004-04-01                 70                22                    48
# 2004-05-01                 72                22                    43

# %%
df.plot()

# %%
df['diet: (Worldwide)'].plot()

# %%
df['gym: (Worldwide)'].plot()

# %%
df['finance: (Worldwide)'].plot()

# %%
diet = df['diet: (Worldwide)']
diet.rolling(12).mean().plot()

# %%
gym = df['gym: (Worldwide)']
gym.rolling(12).mean().plot()

# %%
finance = df['finance: (Worldwide)']
finance.rolling(12).mean().plot()

# %%
diet.diff().plot()
